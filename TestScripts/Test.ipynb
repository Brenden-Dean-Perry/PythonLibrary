# %%
x = [1, 2, 3, 4, 5]
y = [2, 4, 1, 3, 5]
category = ['Equity', 'Fixed', 'Real Asset', 'Commodity', 'Crypto']

# %%
from Visualization.Charting import Charting

# %%
Charting.bar_chart(x,y, title="Cool Chart", horizontal=True)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
Charting.pie_chart(category, y)
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
from DataAccess.AlphaVantage import AlphaVantageAPI
from Utilities.DataUtilities import DataUtilities
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 from DataAccess.AlphaVantage import AlphaVantageAPI
# ----> 2 from Utilities.DataUtilities import DataUtilities
#
# ModuleNotFoundError: No module named 'Utilities.DataUtilities'

# %%
api = AlphaVantageAPI()

# %%
data = api.get_stock_data('IBM')
data

# %%
import pandas as pd
# Out:
# ['1. open', '2. high', '3. low', '4. close', '5. volume']
#                 Open      High       Low     Close   Volume
# 2024-10-07  225.3800  227.6700  225.0200  227.1200  3457952
# 2024-10-04  223.7500  226.0800  223.2700  226.0000  3554328
# 2024-10-03  219.5000  222.8300  219.2700  222.7200  3788265
# 2024-10-02  218.3100  220.2000  215.7980  219.7300  3343399
# 2024-10-01  220.6300  221.1000  215.9000  219.3500  3548374
# ...              ...       ...       ...       ...      ...
# 2024-05-21  169.9400  174.9700  169.9400  173.4700  6459800
# 2024-05-20  169.0000  170.1600  168.3800  169.9200  2726261
# 2024-05-17  168.9700  169.1100  167.3300  169.0300  2956387
# 2024-05-16  168.2600  169.6300  167.7900  168.9700  3492267
# 2024-05-15  167.9400  168.3500  167.3400  168.2600  4468823
#
# [100 rows x 5 columns]

# %%
Charting.line_chart(pd.to_datetime(data.index), pd.to_numeric(data['Close']), 'Date', 'Close Price', 'IBM Equity Price')
# Out:
# <module 'matplotlib.pyplot' from 'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\matplotlib\\pyplot.py'>

# %%
from CustomObjects.TimeSeriesGroup import TimeSeriesGroup
from CustomObjects.TimeSeries import TimeSeries
from CustomObjects.Enums.TimeSeriesPurpose import TimeSeriesPurpose

# %%
series = TimeSeries(data['Close'].to_dict(),'IBM Equity Close Price', TimeSeriesPurpose.Investment)

# %%
series.get_series_index()
# Out:
# dict_keys(['2024-10-07', '2024-10-04', '2024-10-03', '2024-10-02', '2024-10-01', '2024-09-30', '2024-09-27', '2024-09-26', '2024-09-25', '2024-09-24', '2024-09-23', '2024-09-20', '2024-09-19', '2024-09-18', '2024-09-17', '2024-09-16', '2024-09-13', '2024-09-12', '2024-09-11', '2024-09-10', '2024-09-09', '2024-09-06', '2024-09-05', '2024-09-04', '2024-09-03', '2024-08-30', '2024-08-29', '2024-08-28', '2024-08-27', '2024-08-26', '2024-08-23', '2024-08-22', '2024-08-21', '2024-08-20', '2024-08-19', '2024-08-16', '2024-08-15', '2024-08-14', '2024-08-13', '2024-08-12', '2024-08-09', '2024-08-08', '2024-08-07', '2024-08-06', '2024-08-05', '2024-08-02', '2024-08-01', '2024-07-31', '2024-07-30', '2024-07-29', '2024-07-26', '2024-07-25', '2024-07-24', '2024-07-23', '2024-07-22', '2024-07-19', '2024-07-18', '2024-07-17', '2024-07-16', '2024-07-15', '2024-07-12', '2024-07-11', '2024-07-10', '2024-07-09', '2024-07-08', '2024-07-05', '2024-07-03', '2024-07-02', '2024-07-01', '2024-06-28', '2024-0
# ...

# %%
series.get_series_values()
# Out:
# dict_values(['227.1200', '226.0000', '222.7200', '219.7300', '219.3500', '221.0800', '220.8400', '223.4300', '221.2300', '220.9700', '220.5000', '217.7000', '213.8900', '214.9400', '214.1300', '217.1600', '214.7900', '211.6100', '209.8900', '205.3200', '203.5300', '200.7400', '202.5900', '204.1100', '201.2800', '202.1300', '198.9000', '198.4600', '198.7300', '197.9800', '196.1000', '195.9600', '197.2100', '196.0300', '194.7300', '193.7800', '193.9500', '192.3200', '190.9900', '189.4800', '191.4500', '192.6100', '186.8000', '186.8000', '183.3100', '189.1200', '189.6600', '192.1400', '191.0400', '191.5000', '191.7500', '191.9800', '184.0200', '184.1000', '184.1500', '183.2500', '185.2200', '187.4500', '185.8100', '182.8800', '182.8300', '178.3100', '177.8400', '176.4800', '177.6400', '176.0200', '175.7300', '177.3000', '175.1000', '172.9500', '170.8500', '171.8700', '172.6000', '175.0100', '172.4600', '173.9200', '170.5500', '169.5000', '169.2100', '169.1200', '169.0000', '169.3200', '
# ...

# %%
group = TimeSeriesGroup()
group.add_series(series)
series_data = group.get_all_time_series()

# %%
series_data[0].get_time_series_title()
# Out:
# 'IBM Equity Close Price'

# %%
group.get_x_axis_label()
# Out:
# 'Date'

# %%
group.get_y_axis_label()
# Out:
# 'Price'

# %%
item = next(iter(group.get_time_series_by_index(0).get_series_values()))
type(item)
# Out:
# https://www.alphavantage.co/query?function=GLOBAL_QUOTE&symbol=IBM&apikey=demo
# ['index', 'Global Quote']
#                     Index Globalquote
# 0              01. symbol         IBM
# 1                02. open    225.3800
# 2                03. high    227.6700
# 3                 04. low    225.0200
# 4               05. price    227.1200
# 5              06. volume     3457952
# 6  07. latest trading day  2024-10-07
# 7      08. previous close    226.0000
# 8              09. change      1.1200
# 9      10. change percent     0.4956%

# %%
# Out:
# https://www.alphavantage.co/query?function=TIME_SERIES_INTRADAY&symbol=IBM&interval=5min&apikey=demo
# ['1. open', '2. high', '3. low', '4. close', '5. volume']
#                          Open      High       Low     Close  Volume
# 2024-10-07 19:55:00  227.1200  227.4900  227.1200  227.4600      81
# 2024-10-07 19:40:00  227.2300  227.2300  227.1200  227.1200       5
# 2024-10-07 19:25:00  227.1200  227.1200  227.1200  227.1200      30
# 2024-10-07 19:20:00  227.1300  227.1300  227.1300  227.1300       2
# 2024-10-07 19:00:00  227.1200  227.1200  227.1200  227.1200  604346
# ...                       ...       ...       ...       ...     ...
# 2024-10-07 10:55:00  226.1200  226.2700  225.5800  225.6300   39963
# 2024-10-07 10:50:00  225.5450  226.1600  225.5450  226.1599   28329
# 2024-10-07 10:45:00  225.2150  225.5650  225.2000  225.5650   19715
# 2024-10-07 10:40:00  225.2350  225.3400  225.0800  225.2100   23114
# ...
